# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint

# %% [markdown]
# # New Section

# %% [markdown]
# Automated facial expression recognition provides an objective assessment of emotions. Human based assessment of emotions has many limitations and biases and automated facial expression technology has been found to deliver a better level of insight into behavior patterns. Emotion detection from facial expressions using AI is useful in automatically measuring consumers’ engagement with their content and brands, audience engagement for advertisements, customer satisfaction in the retail sector, psychological analyses, law enforcement etc.

# %%
#@title Explanation Video
from IPython.display import HTML

HTML("""<video width="500" height="300" controls>
  <source src="https://cdn.iiith.talentsprint.com/aiml/Experiment_related_data/Hackathon3b_expression_recognition.mp4" type="video/mp4">
</video>
""")
# Out:
# <video width="500" height="300" controls>
#   <source src="https://cdn.iiith.talentsprint.com/aiml/Experiment_related_data/Hackathon3b_expression_recognition.mp4" type="video/mp4">
# </video>

# %% [markdown]
# **Objectives:**
#
# **Stage 4 (15 Marks):** Train a CNN Model and perform Expression Recognition in the EFR Mobile App.
#
# **Stage 5 (5 Marks):** Test for Anti-Face Spoofing on the EFR Mobile App.

# %% [markdown]
# ##**Stage 4 (15 Marks)**
#
# **(i) Train a CNN Model for Expression Recognition on given Expression data
# (ii) Deploy the Model and Perform Expression Recognition on Team Data through the EFR Mobile App**
#
#
# ---
#
#
# * Define and train a CNN for expression recognition for the data under folder "Expression_data" which segregated on expression basis.
# * Collect your team data using EFR application and test your model on the same and optimize the CNN architecture for predicting the respective labels of the images.
# * Save and Download the trained expression model and upload them in the ftp server (refer to [Filezilla Installation and Configuration document](https://drive.google.com/file/d/1hnMXcwpCwAz94ljAhtsJdQSfe-JaOD5K/view?usp=sharing)).
#
# * Update the **“exp_recognition.py”** file in the server. Open the files in the terminal (Command prompt) and provide the code for predicting the expression on the face (Note: To define the architecture of your trained model, you'll need to define it in the file **"exp_recognition_model.py"**).
#
# * Test your model on the mobile app for Expression Recognition and Sequence Expression. Your team can also see your results in your terminal.
#
#
# * Grading Scheme:
# > * Expression Recognition (12M): If the functionality is returning expression class correctly for the face using the mobile app’s “Expression Recognition” functionality
# > * Sequence Expression (3M): Get three consecutive correct Expressions using the mobile app’s “Sequence Expressions” functionality

# %% [markdown]
# **Download the dataset**

# %%
#@title Run this cell to download the dataset

from IPython import get_ipython
ipython = get_ipython()
  
notebook="M3_Hackathon" #name of the notebook

def setup():
#  ipython.magic("sx pip3 install torch")
    ipython.magic("sx wget wget https://cdn.talentsprint.com/aiml/Experiment_related_data/Expression_data.zip")
    
    ipython.magic("sx unzip Expression_data.zip")
    
    ipython.magic("sx pip install torch==1.0.1 -f https://download.pytorch.org/whl/cu100/stable")
    ipython.magic("sx pip install torchvision==0.2.1")
    ipython.magic("sx pip install opencv-python")
    print ("Setup completed successfully")
    return
setup()
# Out:
# Setup completed successfully

# %% [markdown]
# **Dataset attributes:**
#
# During the setup you have downloaded the Expression data:
#
# * **Expression_data**: In this folder, the images are segregrated in terms of Expression
# > * Expressions available: ANGER, DISGUST, FEAR, HAPPINESS, NEUTRAL, SADNESS, SURPRISE
# > * Each class is organised as one folder
# > * There are ~18000 total images in the training data and ~4500 total images in the testing data

# %%
# %ls
# Out:
# Expression_data/  Expression_data.zip  __MACOSX/  sample_data/

# %% [markdown]
# **Imports: All the imports are defined here**
#
# We are installing the following specific package versions -> torch 1.0.1, torchvision 0.2.1 and PIL 5.3.0 to maintain compatibility with the server
#
# * Firstly uninstall and downgrade the current PIL version. In the next cell, you will see a button "Restart Runtime" button appear below.
# * Click on it and select 'Yes' to restart runtime and reset the PIL package.
# * **DO NOT** go to the notebook's **RUNTIME  -> RESTART RUNTIME**. This will restart all packages and you will need to repeat all the steps from beginning.
#
#
# * Simply continue with the next code cell

# %% [markdown]
# PIL (Pillow) is the Python Image Library. Used to cut and resize images, or do simple manipulation.

# %%
# !pip uninstall -y Pillow
# Out:
# Uninstalling Pillow-7.0.0:
#   Successfully uninstalled Pillow-7.0.0

# %%
# IGNORE ERROR. Click on Restart Runtime button and slect 'Yes' if prompts. Then proceed with the next code cell.
# !pip install Pillow==5.3.0
# Out:
# Collecting Pillow==5.3.0
#   Downloading https://files.pythonhosted.org/packages/62/94/5430ebaa83f91cc7a9f687ff5238e26164a779cca2ef9903232268b0a318/Pillow-5.3.0-cp36-cp36m-manylinux1_x86_64.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 16.5MB/s
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: Pillow
# Successfully installed Pillow-5.3.0

# %%
# When you run this, it should give you pil version = 5.3.0
import PIL
print(PIL.__version__)
# Out:
# 5.3.0

# %%
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import os
import warnings
from time import sleep
import sys
warnings.filterwarnings('ignore')

# %% [markdown]
# For the following step, to obtain hints on building a CNN model for face expression, you may refer to this [article](https://drive.google.com/open?id=1P2rpaWW3tOtGGnw4dvtdZ4hjoc8iDNst)

# %% [markdown]
# **Define and train a CNN model for expression recognition**

# %%
# YOUR CODE HERE to define and train CNN model for Expression_Data.
def rgb2gray(image):
	return image.convert('L')

loader = torchvision.transforms.Compose([rgb2gray, torchvision.transforms.Resize((48,48)), torchvision.transforms.ToTensor()])

# %%
# YOUR CODE HERE for the DataLoader
base_dir = '/content/Expression_data'

train_dir = os.path.join(base_dir, 'Facial_expression_train')
validation_dir = os.path.join(base_dir, 'Facial_expression_test')


trainset = dset.ImageFolder(train_dir, transform = loader)
validationset = dset.ImageFolder(validation_dir, transform = loader)




# Load the data. utils.dataloader is a package for loading the dataset 
train_loader = torch.utils.data.DataLoader(trainset, shuffle=True, batch_size=1)
validation_loader = torch.utils.data.DataLoader(validationset, shuffle=True, batch_size=1)

# %%
len(trainset)
# Out:
# 18178

# %%
trainset.class_to_idx
# Out:
# {'ANGER': 0,
#  'DISGUST': 1,
#  'FEAR': 2,
#  'HAPPINESS': 3,
#  'NEUTRAL': 4,
#  'SADNESS': 5,
#  'SURPRISE': 6}

# %%
train_loader.dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 18178
#     Root Location: /content/Expression_data/Facial_expression_train
#     Transforms (if any): Compose(
#                              <function rgb2gray at 0x7fd313228620>
#                              Resize(size=(48, 48), interpolation=PIL.Image.BILINEAR)
#                              ToTensor()
#                          )
#     Target Transforms (if any): None

# %%
current_Images, current_labels = next(iter(train_loader))
current_Images.shape
# Out:
# torch.Size([1, 1, 48, 48])

# %%
current_labels
# Out:
# tensor([4])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# Define the CNN Network

class facExpRec(nn.Module):
    def __init__(self):
        super(facExpRec, self).__init__()

        # Convolution Layer 1  (1*48 * 48)              (64 * 48 * 48)
        self.cnn1 = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=3, stride=1, padding=1) # output size of the first convolutional layer is 64*48*48
        self.bn1 = nn.BatchNorm2d(64)
        self.relu1 = nn.ReLU()
        self.Dropout1 = nn.Dropout(0.5)
        # Maxpool for the Convolutional Layer 1
        self.maxpool1 = nn.MaxPool2d(kernel_size=2, stride=2) 
        # Maxpooling reduces the size by kernel size. After Maxpooling the output size is 64*24*24
        
        # YOUR CODE HERE for defining more number of Convolutional layers with Maxpool as required (Hint: Use at least 3 convolutional layers for better performance)
        # Convolution Layer 2 (64 * 24 * 24)              (128 * 24 * 24)
        self.cnn2 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=5, stride=1, padding=1) 
        self.bn2 = nn.BatchNorm2d(128)
        self.relu2 = nn.ReLU()
        self.Dropout2 = nn.Dropout(0.5)
        # Maxpool for the Convolutional Layer 2
        self.maxpool2 = nn.MaxPool2d(kernel_size=2, stride=2) 
        # Maxpooling reduces the size by kernel size. After Maxpooling the output size is 128 * 12 * 12
        
        # Convolution Layer 3 (128 *12 * 12)              (512 * 12 * 12)
        self.cnn3 = nn.Conv2d(in_channels=128, out_channels=512, kernel_size=3, stride=1, padding=1) 
        self.bn3 = nn.BatchNorm2d(512)
        self.relu3 = nn.ReLU()
        self.Dropout3 = nn.Dropout(0.5)
        # Maxpool for the Convolutional Layer 3
        self.maxpool3 = nn.MaxPool2d(kernel_size=2, stride=2) 
        # Maxpooling reduces the size by kernel size. After Maxpooling the output size is 512 * 6 * 6

        # Convolution Layer 4 (512 * 6 * 6)              (512 * 6 * 6)
        self.cnn4 = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1) 
        self.bn4 = nn.BatchNorm2d(512)
        self.relu4 = nn.ReLU()
        self.Dropout4 = nn.Dropout(0.5)
        # Maxpool for the Convolutional Layer 4
        self.maxpool4 = nn.MaxPool2d(kernel_size=2, stride=2) 
        # Maxpooling reduces the size by kernel size. After Maxpooling the output size is 512 * 3 * 3 

       # Linear layers
        # (512*3*3) input features, 256 output features 
        self.fc1 = nn.Linear(512*3*3, 256)
        self.fc1 = nn.BatchNorm1d(256)
        self.fc1 = nn.Dropout(0.5)
        self.fc1 = nn.ReLU()
        # 256 input features, 512 output features 
        self.fc2 = nn.Linear(256, 512)
        self.fc2 = nn.BatchNorm1d(512)
        self.fc2 = nn.Dropout(0.5)
        self.fc2 = nn.ReLU()       
        # 512 input features, 7 output features 
        self.fc3 = nn.Linear(512, 7)
        self.fc3 = nn.LogSoftmax(dim=1)
 
    def forward(self, x):
        # Convolution Layer 1 and Maxpool
        out = self.cnn1(x)
        out = self.bn1(out)
        out = self.relu1(out)
        out = self.Dropout1(out)
        out = self.maxpool1(out)
        
        # YOUR CODE HERE for the Convolutional Layers and Maxpool based on the defined Convolutional layers
        # Convolution Layer 2 and Maxpool
        out = self.cnn2(out)
        out = self.bn2(out)
        out = self.relu2(out)
        out = self.Dropout2(out)
        out = self.maxpool2(out)
        
        # Convolution Layer 3 and Maxpool
        out = self.cnn3(out)
        out = self.bn3(out)
        out = self.relu3(out)
        out = self.Dropout3(out)
        out = self.maxpool3(out)

        # Convolution Layer 4 and Maxpool
        out = self.cnn4(out)
        out = self.bn4(out)
        out = self.relu4(out)
        out = self.Dropout4(out)
        out = self.maxpool4(out)

        # Flattening
        out = out.view(-1, 2048)

        # Linear layers with RELU activation

        #out = self.fc1(out) 
        out = self.fc1(out)
        out = self.fc2(out)
        out = self.fc3(out)

        return F.log_softmax(out, dim=1)

# %%
myFaceExp = facExpRec()
myFaceExp = myFaceExp.to(device)
myFaceExp
# Out:
# facExpRec(
#   (cnn1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (Dropout1): Dropout(p=0.5)
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (cnn2): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (Dropout2): Dropout(p=0.5)
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (cnn3): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
#   (Dropout3): Dropout(p=0.5)
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (cnn4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu4): ReLU()
#   (Dropout4): Dropout(p=0.5)
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): ReLU()
#   (fc2): ReLU()
#   (fc3): LogSoftmax()
# )

# %%
criterion_Entropy = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(myFaceExp.parameters(), lr = 0.001)

# %%
epoch = 35

# keeping the network in train mode
myFaceExp.train()
train_losses,  train_accuracy = [], []

# Loop for no of epochs
for e in range(epoch):
    train_loss = 0
    correct = 0
    # Iterate through all the batches in each epoch
    for images, labels in train_loader:

      # Convert the image and label to gpu for faster execution
      images = images.to(device)
      labels = labels.to(device)

      # Zero the parameter gradients
      optimizer.zero_grad()

      # Passing the data to the model (Forward Pass)
      outputs = myFaceExp(images)
      
      # Calculating the loss
      loss = criterion_Entropy(outputs, labels)
      train_loss += loss.item()

      # Performing backward pass (Backpropagation)
      loss.backward()

      # optimizer.step() updates the weights accordingly
      optimizer.step()

      # Accuracy calculation
      _, predicted = torch.max(outputs, 1)
      correct += (predicted == labels).sum().item()

    train_losses.append(train_loss/len(trainset))
    train_accuracy.append(100 * correct/len(trainset))
    print('epoch: {}, Train Loss:{:.6f} Train Accuracy: {:.2f} '.format(e+1,train_losses[-1], train_accuracy[-1]))
# Out:
# epoch: 1, Train Loss:2.616712 Train Accuracy: 26.66
# epoch: 2, Train Loss:2.298207 Train Accuracy: 30.12
# epoch: 3, Train Loss:2.297602 Train Accuracy: 31.27
# epoch: 4, Train Loss:2.261336 Train Accuracy: 31.75
# epoch: 5, Train Loss:2.235733 Train Accuracy: 32.99
# epoch: 6, Train Loss:2.229604 Train Accuracy: 33.30
# epoch: 7, Train Loss:2.201246 Train Accuracy: 34.17
# epoch: 8, Train Loss:2.232412 Train Accuracy: 34.48
# epoch: 9, Train Loss:2.208783 Train Accuracy: 34.59
# epoch: 10, Train Loss:2.221708 Train Accuracy: 34.86
# epoch: 11, Train Loss:2.198425 Train Accuracy: 35.38
# epoch: 12, Train Loss:2.200221 Train Accuracy: 35.02
# epoch: 13, Train Loss:2.166004 Train Accuracy: 35.75
# epoch: 14, Train Loss:2.177562 Train Accuracy: 36.47
# epoch: 15, Train Loss:2.148719 Train Accuracy: 36.64
# epoch: 16, Train Loss:2.186855 Train Accuracy: 36.49
# epoch: 17, Train Loss:2.176133 Train Accuracy: 36.26
# epoch: 18, Train Loss:2.137939 Train Accuracy: 36.88
# epoch: 19, Train Loss:2.150990 Train Accuracy: 37.50
# epoch: 20, Train Loss:2.114449 Train Accuracy: 38.22
# epoch: 21, Train Loss:2.145741 Train Accuracy: 37.37
# epoch: 22, Train Loss:2.134061 Train Accuracy: 37.95
# epoch: 23, Train Loss:2.139300 Train Accuracy: 38.39
# epoch: 24, Train Loss:2.133980 Train Accuracy: 38.60
# epoch: 25, Train Loss:2.144535 Train Accuracy: 38.46
# epoch: 26, Train Loss:2.114068 Train Accuracy: 38.95
# epoch: 27, Train Loss:2.120883 Train Accuracy: 39.03
# epoch: 28, Train Loss:2.099360 Train Accuracy: 39.46
# epoch: 29, Train Loss:2.084205 Train Accuracy: 40.11
# epoch: 30, Train Loss:2.129256 Train Accuracy: 39.91
# epoch: 31, Train Loss:2.095973 Train Accuracy: 39.92
# epoch: 32, Train Loss:2.088729 Train Accuracy: 40.09
# epoch: 33, Train Loss:2.092535 Train Accuracy: 40.41
# epoch: 34, Train Loss:2.097071 Train Accuracy: 40.44
# epoch: 35, Train Loss:2.081944 Train Accuracy: 41.14

# %%
## Saving the model as a state dictionary
state = {'face_exp_dict': myFaceExp.state_dict()}
torch.save(state, './face_exp_model.t7')

# %%
myFaceExpModel = facExpRec().cuda()

# %%
ckpt = torch.load('./face_exp_model.t7')
myFaceExpModel.load_state_dict(ckpt['face_exp_dict'])

# %% [markdown]
# **Test your model and optimize CNN architecture for predicting the labels correctly**

# %%
# YOUR CODE HERE for test evaluation

myFaceExpModel.eval()

Test_accuracy = 0

# Iterate through all the batches in each epoch
for images,labels in validation_loader:
    # Convert the images and labels to gpu for faster execution
    images = images.to(device)
    labels = labels.to(device)

    # Do the forward pass 
    outputs = myFaceExpModel(images)

    # Accuracy calculation
    _, predicted = torch.max(outputs, 1)
    Test_accuracy += (predicted == labels).sum().item()

Accuracy = 100 * Test_accuracy / len(validationset)
print("Accuracy of Validation Data is", Accuracy)
# Out:
# Accuracy of Validation Data is 31.31046613896218

# %% [markdown]
# **Team Data Collection (activate the server first)**
#
#   - (This can be done on the day of the Hackathon once the login username and password are given)

# %% [markdown]
# Activate the Server Access
# * Open the terminal (Command Prompt)
# * Login to SSH by typing **ssh (username)@aiml-sandbox1.talentsprint.com**. Give the login username which is given to you.
#
# Eg: `ssh b15h3gxx@aiml-sandbox1.talentsprint.com`
#
#   (If it is your first time connecting to the server from this computer, accept the connection by typing "yes".)
# * After logging into SSH, please activate your virtual environment using the
# command **source venv/bin/activate** and then press enter
# * You can start the server by giving the command **sh runserver.sh** and then press enter.
# * In order to collect team data in mobile app, ensure the server is active

# %% [markdown]
# **Collect your team data using the EFR Mobile App and fine-tune the CNN for expression data on your team**
#
# Team Data Collection
#
# * Follow the "Mobile_APP_Documentation" to collect the Expression photos of your team. These will be stored in the server to which login is provided to you.
#
# [Mobile_APP_Documentation](https://drive.google.com/file/d/1tpr8_U0Ll_TexN4s-0pmPPg23J7Usok2/view?usp=sharing)
#
#
# **Download your team expression data from the EFR app into your colab notebook using the links provided below**
#
# NOTE: Replace the string "username" with your login username (such as b15h3gxx) in the below cell for expression images.
#
# This data will be useful for testing the above trained cnn networks.

# %%
# !wget -nH --recursive --no-parent --reject 'index.*' https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ --cut-dirs=3  -P ./captured_images_with_Expression
# Out:
# --2021-02-18 11:02:11--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/
# Resolving aiml-sandbox.talentsprint.com (aiml-sandbox.talentsprint.com)... 139.162.203.12
# Connecting to aiml-sandbox.talentsprint.com (aiml-sandbox.talentsprint.com)|139.162.203.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘./captured_images_with_Expression/index.html.tmp’
#
# index.html.tmp          [ <=>                ]   1.03K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:11 (103 MB/s) - ‘./captured_images_with_Expression/index.html.tmp’ saved [1054]
#
# Loading robots.txt; please ignore errors.
# --2021-02-18 11:02:11--  https://aiml-sandbox.talentsprint.com/robots.txt
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-02-18 11:02:11 ERROR 404: Not Found.
#
# Removing ./captured_images_with_Expression/index.html.tmp since it should be rejected.
#
# --2021-02-18 11:02:11--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘./captured_images_with_Expression/ANGER/index.html.tmp’
#
# ANGER/index.html.tm     [ <=>                ]   2.22K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:11 (230 MB/s) - ‘./captured_images_with_Expression/ANGER/index.html.tmp’ saved [2277]
#
# Removing ./captured_images_with_Expression/ANGER/index.html.tmp since it should be rejected.
#
# --2021-02-18 11:02:11--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘./captured_images_with_Expression/DISGUST/index.html.tmp’
#
# DISGUST/index.html.     [ <=>                ]   2.01K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:11 (228 MB/s) - ‘./captured_images_with_Expression/DISGUST/index.html.tmp’ saved [2059]
#
# Removing ./captured_images_with_Expression/DISGUST/index.html.tmp since it should be rejected.
#
# --2021-02-18 11:02:11--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘./captured_images_with_Expression/FEAR/index.html.tmp’
#
# FEAR/index.html.tmp     [ <=>                ]   2.21K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:12 (239 MB/s) - ‘./captured_images_with_Expression/FEAR/index.html.tmp’ saved [2259]
#
# Removing ./captured_images_with_Expression/FEAR/index.html.tmp since it should be rejected.
#
# --2021-02-18 11:02:12--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/index.html.tmp’
#
# HAPPINESS/index.htm     [ <=>                ]   3.55K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:12 (394 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/index.html.tmp’ saved [3639]
#
# Removing ./captured_images_with_Expression/HAPPINESS/index.html.tmp since it should be rejected.
#
# --2021-02-18 11:02:12--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/NEUTRAL/
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘./captured_images_with_Expression/NEUTRAL/index.html.tmp’
#
# NEUTRAL/index.html.     [ <=>                ]   6.35K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:12 (468 MB/s) - ‘./captured_images_with_Expression/NEUTRAL/index.html.tmp’ saved [6504]
#
# Removing ./captured_images_with_Expression/NEUTRAL/index.html.tmp since it should be rejected.
#
# --2021-02-18 11:02:12--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SADNESS/
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘./captured_images_with_Expression/SADNESS/index.html.tmp’
#
# SADNESS/index.html.     [ <=>                ]   4.12K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:12 (331 MB/s) - ‘./captured_images_with_Expression/SADNESS/index.html.tmp’ saved [4218]
#
# Removing ./captured_images_with_Expression/SADNESS/index.html.tmp since it should be rejected.
#
# --2021-02-18 11:02:12--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/index.html.tmp’
#
# SURPRISE/index.html     [ <=>                ]   3.53K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:12 (387 MB/s) - ‘./captured_images_with_Expression/SURPRISE/index.html.tmp’ saved [3611]
#
# Removing ./captured_images_with_Expression/SURPRISE/index.html.tmp since it should be rejected.
#
# --2021-02-18 11:02:12--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613279249.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3271 (3.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613279249.jpg’
#
# ANGER/ANGER_1613279 100%[===================>]   3.19K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:12 (534 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613279249.jpg’ saved [3271/3271]
#
# --2021-02-18 11:02:12--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613279288.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4626 (4.5K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613279288.jpg’
#
# ANGER/ANGER_1613279 100%[===================>]   4.52K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:12 (825 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613279288.jpg’ saved [4626/4626]
#
# --2021-02-18 11:02:12--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613279302.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4246 (4.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613279302.jpg’
#
# ANGER/ANGER_1613279 100%[===================>]   4.15K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:12 (698 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613279302.jpg’ saved [4246/4246]
#
# --2021-02-18 11:02:12--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613279353.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6249 (6.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613279353.jpg’
#
# ANGER/ANGER_1613279 100%[===================>]   6.10K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:12 (1.05 GB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613279353.jpg’ saved [6249/6249]
#
# --2021-02-18 11:02:12--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613279364.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3615 (3.5K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613279364.jpg’
#
# ANGER/ANGER_1613279 100%[===================>]   3.53K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:12 (736 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613279364.jpg’ saved [3615/3615]
#
# --2021-02-18 11:02:12--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613281804.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4204 (4.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613281804.jpg’
#
# ANGER/ANGER_1613281 100%[===================>]   4.11K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:12 (912 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613281804.jpg’ saved [4204/4204]
#
# --2021-02-18 11:02:12--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613281835.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4876 (4.8K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613281835.jpg’
#
# ANGER/ANGER_1613281 100%[===================>]   4.76K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:12 (876 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613281835.jpg’ saved [4876/4876]
#
# --2021-02-18 11:02:12--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613281849.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4446 (4.3K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613281849.jpg’
#
# ANGER/ANGER_1613281 100%[===================>]   4.34K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:12 (780 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613281849.jpg’ saved [4446/4446]
#
# --2021-02-18 11:02:12--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613281868.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4817 (4.7K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613281868.jpg’
#
# ANGER/ANGER_1613281 100%[===================>]   4.70K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:13 (815 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613281868.jpg’ saved [4817/4817]
#
# --2021-02-18 11:02:13--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613281878.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3965 (3.9K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613281878.jpg’
#
# ANGER/ANGER_1613281 100%[===================>]   3.87K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:13 (830 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613281878.jpg’ saved [3965/3965]
#
# --2021-02-18 11:02:13--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613281890.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4297 (4.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613281890.jpg’
#
# ANGER/ANGER_1613281 100%[===================>]   4.20K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:13 (827 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613281890.jpg’ saved [4297/4297]
#
# --2021-02-18 11:02:13--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613283055.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4875 (4.8K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613283055.jpg’
#
# ANGER/ANGER_1613283 100%[===================>]   4.76K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:13 (994 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613283055.jpg’ saved [4875/4875]
#
# --2021-02-18 11:02:13--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613283056.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3807 (3.7K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613283056.jpg’
#
# ANGER/ANGER_1613283 100%[===================>]   3.72K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:13 (837 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613283056.jpg’ saved [3807/3807]
#
# --2021-02-18 11:02:13--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613283096.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4821 (4.7K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613283096.jpg’
#
# ANGER/ANGER_1613283 100%[===================>]   4.71K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:13 (923 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613283096.jpg’ saved [4821/4821]
#
# --2021-02-18 11:02:13--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613283111.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4690 (4.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613283111.jpg’
#
# ANGER/ANGER_1613283 100%[===================>]   4.58K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:13 (931 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613283111.jpg’ saved [4690/4690]
#
# --2021-02-18 11:02:13--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/ANGER/ANGER_1613283124.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4392 (4.3K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/ANGER/ANGER_1613283124.jpg’
#
# ANGER/ANGER_1613283 100%[===================>]   4.29K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:13 (743 MB/s) - ‘./captured_images_with_Expression/ANGER/ANGER_1613283124.jpg’ saved [4392/4392]
#
# --2021-02-18 11:02:13--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613278651.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3205 (3.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613278651.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   3.13K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:13 (593 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613278651.jpg’ saved [3205/3205]
#
# --2021-02-18 11:02:13--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613278774.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4334 (4.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613278774.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   4.23K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:13 (918 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613278774.jpg’ saved [4334/4334]
#
# --2021-02-18 11:02:13--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613278931.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3484 (3.4K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613278931.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   3.40K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:13 (642 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613278931.jpg’ saved [3484/3484]
#
# --2021-02-18 11:02:13--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613279032.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4249 (4.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613279032.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   4.15K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:13 (801 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613279032.jpg’ saved [4249/4249]
#
# --2021-02-18 11:02:13--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613279043.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5789 (5.7K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613279043.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   5.65K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:13 (850 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613279043.jpg’ saved [5789/5789]
#
# --2021-02-18 11:02:13--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613281353.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3482 (3.4K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281353.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   3.40K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:14 (602 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281353.jpg’ saved [3482/3482]
#
# --2021-02-18 11:02:14--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613281595.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3010 (2.9K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281595.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   2.94K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:14 (544 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281595.jpg’ saved [3010/3010]
#
# --2021-02-18 11:02:14--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613281624.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4233 (4.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281624.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   4.13K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:14 (838 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281624.jpg’ saved [4233/4233]
#
# --2021-02-18 11:02:14--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613281637.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4522 (4.4K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281637.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   4.42K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:14 (910 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281637.jpg’ saved [4522/4522]
#
# --2021-02-18 11:02:14--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613281648.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2561 (2.5K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281648.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   2.50K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:14 (544 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281648.jpg’ saved [2561/2561]
#
# --2021-02-18 11:02:14--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613281664.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2653 (2.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281664.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   2.59K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:14 (610 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281664.jpg’ saved [2653/2653]
#
# --2021-02-18 11:02:14--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613281690.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2626 (2.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281690.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:14 (457 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281690.jpg’ saved [2626/2626]
#
# --2021-02-18 11:02:14--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613281718.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4248 (4.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281718.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   4.15K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:14 (771 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281718.jpg’ saved [4248/4248]
#
# --2021-02-18 11:02:14--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/DISGUST/DISGUST_1613281732.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3061 (3.0K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281732.jpg’
#
# DISGUST/DISGUST_161 100%[===================>]   2.99K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:14 (623 MB/s) - ‘./captured_images_with_Expression/DISGUST/DISGUST_1613281732.jpg’ saved [3061/3061]
#
# --2021-02-18 11:02:14--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613279552.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2650 (2.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613279552.jpg’
#
# FEAR/FEAR_161327955 100%[===================>]   2.59K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:14 (511 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613279552.jpg’ saved [2650/2650]
#
# --2021-02-18 11:02:14--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613279688.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3478 (3.4K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613279688.jpg’
#
# FEAR/FEAR_161327968 100%[===================>]   3.40K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:14 (702 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613279688.jpg’ saved [3478/3478]
#
# --2021-02-18 11:02:14--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613279755.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4120 (4.0K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613279755.jpg’
#
# FEAR/FEAR_161327975 100%[===================>]   4.02K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:14 (707 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613279755.jpg’ saved [4120/4120]
#
# --2021-02-18 11:02:14--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613279804.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5347 (5.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613279804.jpg’
#
# FEAR/FEAR_161327980 100%[===================>]   5.22K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:14 (1.03 GB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613279804.jpg’ saved [5347/5347]
#
# --2021-02-18 11:02:14--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613279930.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5370 (5.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613279930.jpg’
#
# FEAR/FEAR_161327993 100%[===================>]   5.24K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:15 (964 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613279930.jpg’ saved [5370/5370]
#
# --2021-02-18 11:02:15--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613281232.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3827 (3.7K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613281232.jpg’
#
# FEAR/FEAR_161328123 100%[===================>]   3.74K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:15 (775 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613281232.jpg’ saved [3827/3827]
#
# --2021-02-18 11:02:15--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613281257.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3214 (3.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613281257.jpg’
#
# FEAR/FEAR_161328125 100%[===================>]   3.14K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:15 (739 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613281257.jpg’ saved [3214/3214]
#
# --2021-02-18 11:02:15--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613281297.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3608 (3.5K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613281297.jpg’
#
# FEAR/FEAR_161328129 100%[===================>]   3.52K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:15 (770 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613281297.jpg’ saved [3608/3608]
#
# --2021-02-18 11:02:15--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613281429.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3422 (3.3K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613281429.jpg’
#
# FEAR/FEAR_161328142 100%[===================>]   3.34K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:15 (727 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613281429.jpg’ saved [3422/3422]
#
# --2021-02-18 11:02:15--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613281442.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3362 (3.3K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613281442.jpg’
#
# FEAR/FEAR_161328144 100%[===================>]   3.28K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:15 (606 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613281442.jpg’ saved [3362/3362]
#
# --2021-02-18 11:02:15--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613281463.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2456 (2.4K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613281463.jpg’
#
# FEAR/FEAR_161328146 100%[===================>]   2.40K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:15 (106 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613281463.jpg’ saved [2456/2456]
#
# --2021-02-18 11:02:15--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613281474.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3426 (3.3K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613281474.jpg’
#
# FEAR/FEAR_161328147 100%[===================>]   3.35K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:15 (303 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613281474.jpg’ saved [3426/3426]
#
# --2021-02-18 11:02:15--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613281489.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3278 (3.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613281489.jpg’
#
# FEAR/FEAR_161328148 100%[===================>]   3.20K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:15 (683 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613281489.jpg’ saved [3278/3278]
#
# --2021-02-18 11:02:15--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613281533.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2720 (2.7K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613281533.jpg’
#
# FEAR/FEAR_161328153 100%[===================>]   2.66K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:15 (539 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613281533.jpg’ saved [2720/2720]
#
# --2021-02-18 11:02:15--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613281552.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3303 (3.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613281552.jpg’
#
# FEAR/FEAR_161328155 100%[===================>]   3.23K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:15 (701 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613281552.jpg’ saved [3303/3303]
#
# --2021-02-18 11:02:15--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/FEAR/FEAR_1613281575.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2744 (2.7K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/FEAR/FEAR_1613281575.jpg’
#
# FEAR/FEAR_161328157 100%[===================>]   2.68K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:15 (557 MB/s) - ‘./captured_images_with_Expression/FEAR/FEAR_1613281575.jpg’ saved [2744/2744]
#
# --2021-02-18 11:02:15--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279107.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3026 (3.0K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279107.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   2.96K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:15 (584 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279107.jpg’ saved [3026/3026]
#
# --2021-02-18 11:02:15--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279122.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3263 (3.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279122.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   3.19K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:16 (686 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279122.jpg’ saved [3263/3263]
#
# --2021-02-18 11:02:16--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279124.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4864 (4.8K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279124.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   4.75K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:16 (866 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279124.jpg’ saved [4864/4864]
#
# --2021-02-18 11:02:16--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279149.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4332 (4.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279149.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   4.23K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:16 (660 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279149.jpg’ saved [4332/4332]
#
# --2021-02-18 11:02:16--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279163.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6202 (6.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279163.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   6.06K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:16 (1.06 GB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613279163.jpg’ saved [6202/6202]
#
# --2021-02-18 11:02:16--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281078.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3306 (3.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281078.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   3.23K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:16 (634 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281078.jpg’ saved [3306/3306]
#
# --2021-02-18 11:02:16--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281148.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5849 (5.7K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281148.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   5.71K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:16 (1.02 GB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281148.jpg’ saved [5849/5849]
#
# --2021-02-18 11:02:16--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281158.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4861 (4.7K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281158.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   4.75K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:16 (955 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281158.jpg’ saved [4861/4861]
#
# --2021-02-18 11:02:16--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281170.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5699 (5.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281170.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   5.57K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:16 (1.03 GB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281170.jpg’ saved [5699/5699]
#
# --2021-02-18 11:02:16--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281230.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5510 (5.4K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281230.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   5.38K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:16 (1.17 GB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281230.jpg’ saved [5510/5510]
#
# --2021-02-18 11:02:16--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281244.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5322 (5.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281244.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   5.20K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:16 (1.05 GB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281244.jpg’ saved [5322/5322]
#
# --2021-02-18 11:02:16--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281256.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3706 (3.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281256.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   3.62K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:16 (746 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281256.jpg’ saved [3706/3706]
#
# --2021-02-18 11:02:16--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281257.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5977 (5.8K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281257.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   5.84K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:16 (995 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281257.jpg’ saved [5977/5977]
#
# --2021-02-18 11:02:16--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281268.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5252 (5.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281268.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   5.13K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:16 (1.16 GB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281268.jpg’ saved [5252/5252]
#
# --2021-02-18 11:02:16--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281271.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3880 (3.8K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281271.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   3.79K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:17 (857 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281271.jpg’ saved [3880/3880]
#
# --2021-02-18 11:02:17--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281278.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4979 (4.9K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281278.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   4.86K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:17 (985 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281278.jpg’ saved [4979/4979]
#
# --2021-02-18 11:02:17--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281284.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4171 (4.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281284.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   4.07K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:17 (862 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281284.jpg’ saved [4171/4171]
#
# --2021-02-18 11:02:17--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281293.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5718 (5.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281293.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   5.58K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:17 (1.05 GB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281293.jpg’ saved [5718/5718]
#
# --2021-02-18 11:02:17--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281295.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3666 (3.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281295.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   3.58K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:17 (816 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281295.jpg’ saved [3666/3666]
#
# --2021-02-18 11:02:17--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281306.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5708 (5.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281306.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   5.57K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:17 (1.14 GB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281306.jpg’ saved [5708/5708]
#
# --2021-02-18 11:02:17--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281312.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2103 (2.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281312.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   2.05K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:17 (451 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281312.jpg’ saved [2103/2103]
#
# --2021-02-18 11:02:17--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281323.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2403 (2.3K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281323.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   2.35K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:17 (534 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281323.jpg’ saved [2403/2403]
#
# --2021-02-18 11:02:17--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281338.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2079 (2.0K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281338.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   2.03K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:17 (448 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281338.jpg’ saved [2079/2079]
#
# --2021-02-18 11:02:17--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281353.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2178 (2.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281353.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   2.13K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:17 (435 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281353.jpg’ saved [2178/2178]
#
# --2021-02-18 11:02:17--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281367.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2706 (2.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281367.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   2.64K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:17 (532 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281367.jpg’ saved [2706/2706]
#
# --2021-02-18 11:02:17--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281378.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3025 (3.0K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281378.jpg’
#
# HAPPINESS/HAPPINESS 100%[===================>]   2.95K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:17 (642 MB/s) - ‘./captured_images_with_Expression/HAPPINESS/HAPPINESS_1613281378.jpg’ saved [3025/3025]
#
# --2021-02-18 11:02:17--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/NEUTRAL/NEUTRAL_1613279810.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3473 (3.4K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/NEUTRAL/NEUTRAL_1613279810.jpg’
#
# NEUTRAL/NEUTRAL_161 100%[===================>]   3.39K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:17 (823 MB/s) - ‘./captured_images_with_Expression/NEUTRAL/NEUTRAL_1613279810.jpg’ saved [3473/3473]
#
# --2021-02-18 11:02:17--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/NEUTRAL/NEUTRAL_1613279988.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4207 (4.1K) [image/jpeg]
# ...
#
# --2021-02-18 11:02:24--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SADNESS/SADNESS_1613281298.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3776 (3.7K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SADNESS/SADNESS_1613281298.jpg’
#
# SADNESS/SADNESS_161 100%[===================>]   3.69K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:24 (847 MB/s) - ‘./captured_images_with_Expression/SADNESS/SADNESS_1613281298.jpg’ saved [3776/3776]
#
# --2021-02-18 11:02:24--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280080.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4685 (4.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280080.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.58K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:24 (780 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280080.jpg’ saved [4685/4685]
#
# --2021-02-18 11:02:24--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280132.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4281 (4.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280132.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.18K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:24 (754 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280132.jpg’ saved [4281/4281]
#
# --2021-02-18 11:02:24--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280189.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5728 (5.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280189.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   5.59K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:24 (1.15 GB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280189.jpg’ saved [5728/5728]
#
# --2021-02-18 11:02:24--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280196.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5698 (5.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280196.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   5.56K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:24 (1.40 GB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280196.jpg’ saved [5698/5698]
#
# --2021-02-18 11:02:24--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280211.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4235 (4.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280211.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.14K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:24 (833 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280211.jpg’ saved [4235/4235]
#
# --2021-02-18 11:02:24--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280858.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5473 (5.3K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280858.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   5.34K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:24 (883 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280858.jpg’ saved [5473/5473]
#
# --2021-02-18 11:02:24--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280871.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5024 (4.9K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280871.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.91K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:24 (1011 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280871.jpg’ saved [5024/5024]
#
# --2021-02-18 11:02:24--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280887.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4942 (4.8K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280887.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.83K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:24 (1004 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280887.jpg’ saved [4942/4942]
#
# --2021-02-18 11:02:24--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280901.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4287 (4.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280901.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.19K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:25 (974 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280901.jpg’ saved [4287/4287]
#
# --2021-02-18 11:02:25--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280915.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4444 (4.3K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280915.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.34K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:25 (903 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280915.jpg’ saved [4444/4444]
#
# --2021-02-18 11:02:25--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280919.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4501 (4.4K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280919.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.40K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:25 (952 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280919.jpg’ saved [4501/4501]
#
# --2021-02-18 11:02:25--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280935.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4345 (4.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280935.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.24K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:25 (1.03 GB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280935.jpg’ saved [4345/4345]
#
# --2021-02-18 11:02:25--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280943.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5500 (5.4K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280943.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   5.37K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:25 (1.11 GB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280943.jpg’ saved [5500/5500]
#
# --2021-02-18 11:02:25--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280950.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3969 (3.9K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280950.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   3.88K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:25 (867 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280950.jpg’ saved [3969/3969]
#
# --2021-02-18 11:02:25--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280959.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5900 (5.8K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280959.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   5.76K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:25 (1.11 GB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280959.jpg’ saved [5900/5900]
#
# --2021-02-18 11:02:25--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280964.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4745 (4.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280964.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.63K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:25 (1.05 GB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280964.jpg’ saved [4745/4745]
#
# --2021-02-18 11:02:25--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280977.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4831 (4.7K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280977.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.72K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:25 (1.02 GB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280977.jpg’ saved [4831/4831]
#
# --2021-02-18 11:02:25--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613280982.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5767 (5.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280982.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   5.63K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:25 (1.24 GB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613280982.jpg’ saved [5767/5767]
#
# --2021-02-18 11:02:25--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613281149.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2019 (2.0K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281149.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   1.97K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:25 (441 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281149.jpg’ saved [2019/2019]
#
# --2021-02-18 11:02:25--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613281340.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5357 (5.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281340.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   5.23K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:25 (1.01 GB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281340.jpg’ saved [5357/5357]
#
# --2021-02-18 11:02:25--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613281398.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5648 (5.5K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281398.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   5.52K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:26 (962 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281398.jpg’ saved [5648/5648]
#
# --2021-02-18 11:02:26--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613281463.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4844 (4.7K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281463.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.73K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:26 (1.09 GB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281463.jpg’ saved [4844/4844]
#
# --2021-02-18 11:02:26--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613281497.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4809 (4.7K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281497.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.70K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:26 (1.03 GB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281497.jpg’ saved [4809/4809]
#
# --2021-02-18 11:02:26--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613281523.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4741 (4.6K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281523.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   4.63K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:26 (921 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281523.jpg’ saved [4741/4741]
#
# --2021-02-18 11:02:26--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613281553.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5251 (5.1K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281553.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   5.13K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:26 (876 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281553.jpg’ saved [5251/5251]
#
# --2021-02-18 11:02:26--  https://aiml-sandbox.talentsprint.com/expression_detection/b15h3g17/captured_images_with_Expression/SURPRISE/SURPRISE_1613281586.jpg
# Reusing existing connection to aiml-sandbox.talentsprint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5375 (5.2K) [image/jpeg]
# Saving to: ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281586.jpg’
#
# SURPRISE/SURPRISE_1 100%[===================>]   5.25K  --.-KB/s    in 0s
#
# 2021-02-18 11:02:26 (880 MB/s) - ‘./captured_images_with_Expression/SURPRISE/SURPRISE_1613281586.jpg’ saved [5375/5375]
#
# FINISHED --2021-02-18 11:02:26--
# Total wall clock time: 15s
# Downloaded: 186 files, 768K in 0.001s (773 MB/s)

# %%
# %ls
# Out:
# captured_images_with_Expression/  Expression_data.zip  __MACOSX/
# Expression_data/                  face_exp_model.t7    sample_data/

# %%
team_test_dir = '/content/captured_images_with_Expression'
teamTestSet = dset.ImageFolder(team_test_dir, transform = loader)
team_loader = torch.utils.data.DataLoader(teamTestSet, shuffle=True, batch_size=1)

# %%
# YOUR CODE HERE for loading the team expression data. Note: Use the same transform which used for Expression_Data.
# YOU CODE HERE for Dataloader

myFaceExpModel.eval()

Test_accuracy = 0

# Iterate through all the batches in each epoch
for images,labels in team_loader:
    # Convert the images and labels to gpu for faster execution
    images = images.to(device)
    labels = labels.to(device)

    # Do the forward pass 
    outputs = myFaceExpModel(images)

    # Accuracy calculation
    _, predicted = torch.max(outputs, 1)
    Test_accuracy += (predicted == labels).sum().item()

Accuracy = 100 * Test_accuracy / len(teamTestSet)
print("Accuracy of Team's Data is", Accuracy)
# Out:
# Accuracy of Team's Data is 38.764044943820224

# %%
# YOUR CODE HERE for getting the CNN representation of your team data with expression. Optimize the CNN model for predicting the labels of expressions correctly

# %% [markdown]
# **Save your trained model**
#
# * Save the state dictionary of the classifier (use pytorch only), It will be useful in
# integrating model to the mobile app
#
#  [Hint](https://pytorch.org/tutorials/beginner/saving_loading_models.html)

# %%
### YOUR CODE HERE for saving the CNN model

# %% [markdown]
# **Download your trained model**
# * Given the path of model file the following code downloads it through the browser

# %%
from google.colab import files
files.download('<model_file_path>')

# %% [markdown]
# ##**Stage 5 (Anti Face Spoofing): (5 marks)**
#
#
# ---
#
#
#
# The objective of anti face spoofing is to be able to unlock (say) a screen not just by your image
# (which can be easily be spoofed with a photograph of yours) but by a switch in the expression
# demanded by the Mobile App (which is much less probable to mimic)
# * **Grading scheme**:
# > * **Anti Face Spoofing**: (5M Only if both the cases mentioned below are achieved)
# >>* **Unlock**: Correct face + Correct Demanded Expression
# >>* **Stay Locked**: Correct face + Incorrect Demanded Expression (as you might imagine there are multiple other such possibilities, which you are free to explore)

# %%
# Test in your mobile app and see if it gets unlock.
